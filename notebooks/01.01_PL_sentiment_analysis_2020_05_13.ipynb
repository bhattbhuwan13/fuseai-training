# %%
import numpy as np
import pandas as pd
from collections import Counter

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk

# %%
from sklearn.naive_bayes import MultinomialNB

# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# %%
datas = pd.read_csv('datasets/ISEAR.csv')

# %%
datas.head()
# Out:
#    0      joy  \
# 0  1     fear
# 1  2    anger
# 2  3  sadness
# 3  4  disgust
# 4  5    shame
#
#   On days when I feel close to my partner and other friends.   \nWhen I feel at peace with myself and also experience a close  \ncontact with people whom I regard greatly.
# 0  Every time I imagine that someone I love or I ...
# 1  When I had been obviously unjustly treated and...
# 2  When I think about the short time that we live...
# 3  At a gathering I found myself involuntarily si...
# 4  When I realized that I was directing the feeli...

# %%
datas.columns
# Out:
# Index(['0', 'joy',
#        'On days when I feel close to my partner and other friends.   \nWhen I feel at peace with myself and also experience a close  \ncontact with people whom I regard greatly.'],
#       dtype='object')

# %%
datas.drop('0', axis=1, inplace=True)

# %%
datas.size
# Out:
# 14890

# %%
datas.shape
# Out:
# (7445, 2)

# %%
column_name = datas.columns

# %%
datas = datas.rename(columns={column_name[0]: "Emotion",
                             column_name[1]: "Sentence"})

# %%
datas.head()
# Out:
#    Emotion                                           Sentence
# 0     fear  Every time I imagine that someone I love or I ...
# 1    anger  When I had been obviously unjustly treated and...
# 2  sadness  When I think about the short time that we live...
# 3  disgust  At a gathering I found myself involuntarily si...
# 4    shame  When I realized that I was directing the feeli...

# %% [markdown]
# Adding $joy$ back to the dataset

# %%
missing_data = {"Emotion": column_name[0],
                "Sentence": column_name[1]}

# %%
missing_data
# Out:
# {'Emotion': 'joy',
#  'Sentence': 'On days when I feel close to my partner and other friends.   \nWhen I feel at peace with myself and also experience a close  \ncontact with people whom I regard greatly.'}

# %%
datas = datas.append(missing_data, ignore_index=True)

# %%
datas.isna().sum()
# Out:
# Emotion     0
# Sentence    0
# dtype: int64

# %%
datas.tail()
# Out:
#       Emotion                                           Sentence
# 7441  sadness  When I was ill and had to stay at the hospital...
# 7442  disgust  A few days back I was waiting for the bus at t...
# 7443    shame  A few days back I had a tutorial class and the...
# 7444    guilt  Once I quarrelled with my sister and after thi...
# 7445      joy  On days when I feel close to my partner and ot...

# %%
y = datas['Emotion']

# %%
y.head()
# Out:
# 0       fear
# 1      anger
# 2    sadness
# 3    disgust
# 4      shame
# Name: Emotion, dtype: object

# %%
X = datas['Sentence']

# %%
X.head()
# Out:
# 0    Every time I imagine that someone I love or I ...
# 1    When I had been obviously unjustly treated and...
# 2    When I think about the short time that we live...
# 3    At a gathering I found myself involuntarily si...
# 4    When I realized that I was directing the feeli...
# Name: Sentence, dtype: object

# %%
Counter(y)
# Out:
# Counter({'fear': 1063,
#          'anger': 1069,
#          'sadness': 1074,
#          'disgust': 1059,
#          'shame': 1059,
#          'guilt': 1040,
#          'joy': 1082})

# %%
tfidf = TfidfVectorizer(tokenizer=nltk.word_tokenize, stop_words='english', min_df=3, ngram_range=(1, 3))

# %%
X = tfidf.fit_transform(X)

# %%
tfidf.vocabulary_
# Out:
# {'time': 6373,
#  'imagine': 3759,
#  'love': 4228,
#  'contact': 2007,
#  'illness': 3755,
#  ',': 119,
#  'death': 2185,
#  '.': 473,
#  'illness ,': 3756,
#  'death .': 2187,
#  'obviously': 4729,
#  'unjustly': 6629,
#  'treated': 6488,
#  'possibility': 5089,
#  'think': 6337,
#  'short': 5804,
#  'live': 4152,
#  'life': 4104,
#  'did': 2263,
#  'use': 6652,
#  'short time': 5806,
#  'think did': 6340,
#  'time .': 6380,
#  'short time .': 5807,
#  'gathering': 3239,
#  'sitting': 5863,
#  'people': 4941,
#  'expressed': 2726,
#  'opinions': 4792,
#  'considered': 2002,
#  'low': 4246,
#  'realized': 5315,
#  'feelings': 2873,
#  'discontent': 2388,
#  'partner': 4885,
#  'way': 6779,
#  'trying': 6535,
#  'blame': 1426,
#  'instead': 3812,
#  'feel': 2846,
#  'guilty': 3474,
#  'realize': 5314,
#  'consider': 1999,
#  'material': 4328,
#  'things': 6329,
#  'important': 3768,
#  'relatives': 5413,
#  'feel guilty': 2859,
#  'relatives .': 5414,
#  '. feel': 596,
#  'girlfriend': 3289,
#  'taken': 6212,
#  'exam': 2664,
#  'went': 6813,
#  'parent': 4855,
#  "'s": 23,
#  'place': 5033,
#  'taken exam': 6217,
#  "parent 's": 4856,
#  "'s place": 66,
#  'place .': 5035,
#  "parent 's place": 4858,
#  "'s place .": 67,
#  'meaning': 4344,
#  ', time': 424,
#  'car': 1652,
#  'forced': 3069,
#  'drive': 2499,
#  'road': 5509,
#  'road .': 5511,
#  'recently': 5361,
#  'thought': 6347,
#  'hard': 3529,
#  'work': 6893,
#  'takes': 6219,
#  'study': 6125,
#  'wants': 6749,
#  'try': 6533,
#  'read': 5301,
#  'book': 1456,
#  'english': 2605,
#  'understand': 6580,
#  'hard work': 3531,
#  'study ,': 6126,
#  '. read': 725,
#  'did understand': 2330,
#  'understand .': 6581,
#  'tube': 6537,
#  'tired': 6400,
#  'shouted': 5813,
#  'brought': 1563,
#  'negative': 4644,
#  'character': 1752,
#  'actually': 1004,
#  ', shouted': 388,
#  'important .': 3770,
#  'weekend': 6801,
#  'able': 935,
#  'study .': 6127,
#  'pass': 4894,
#  'examination': 2672,
#  'pass examination': 4896,
#  'did think': 2326,
#  'did .': 2265,
#  'arranged': 1182,
#  'meet': 4362,
#  'person': 4975,
#  'late': 3994,
#  'meantime': 4347,
#  'thinking': 6342,
#  'gone': 3337,
#  'wrong': 6932,
#  'e.g': 2537,
#  'traffic': 6468,
#  'accident': 971,
#  'meet person': 4366,
#  'late ,': 3995,
#  'traffic accident': 6469,
#  'accident .': 973,
#  'traffic accident .': 6470,
#  'accused': 983,
#  'studies': 6123,
#  'difficult': 2357,
#  'know': 3957,
#  'like': 4116,
#  'instance': 3810,
#  'friends': 3181,
#  'steal': 6058,
#  'quite': 5259,
#  'thought ,': 6348,
#  'things like': 6336,
#  'like ,': 4118,
#  ', quite': 357,
#  'unjust': 6625,
#  'stupid': 6133,
#  'unjust ,': 6626,
#  'stupid .': 6135,
#  'neglected': 4648,
#  'good': 3341,
#  'friend': 3110,
#  'good friend': 3345,
#  'friend .': 3122,
#  'good friend .': 3347,
#  'passing': 4921,
#  'expect': 2701,
#  'exam did': 2667,
#  'pass .': 4895,
#  'climbed': 1856,
#  'tree': 6497,
#  'pick': 5021,
#  'apples': 1143,
#  'ladder': 3976,
#  'high': 3605,
#  'implied': 3766,
#  'stable': 6003,
#  'high .': 3607,
#  'necessary': 4637,
#  'doing': 2459,
#  'doing .': 2460,
#  'children': 1781,
#  'children .': 1784,
#  '2': 859,
#  'year': 6943,
#  'old': 4753,
#  'son': 5935,
#  'sat': 5594,
#  '7th': 899,
#  'floor': 3038,
#  'legs': 4067,
#  'hanging': 3510,
#  'holding': 3625,
#  'upper': 6644,
#  'easily': 2551,
#  'lost': 4208,
#  '2 year': 863,
#  'year old': 6952,
#  'old son': 4764,
#  'sat .': 5595,
#  '2 year old': 864,
#  'year old son': 6954,
#  'attacked': 1245,
#  't.v': 6206,
#  'war': 6750,
#  'war .': 6751,
#  'nearly': 4634,
#  'walked': 6720,
#  'saw': 5607,
#  'away': 1282,
#  'away .': 1284,
#  '18': 851,
#  'difficulties': 2359,
#  'bad': 1304,
#  'conscience': 1991,
#  'stopped': 6081,
#  'smoking': 5913,
#  'caused': 1709,
#  'sense': 5734,
#  'guilt': 3468,
#  'difficulties .': 2360,
#  '. bad': 507,
#  'sense guilt': 5735,
#  'guilt .': 3472,
#  'sense guilt .': 5736,
#  'experience': 2711,
#  'middle': 4407,
#  'express': 2724,
#  'verbally': 6673,
#  'writing': 6929,
#  'child': 1770,
#  'born': 1464,
#  'born .': 1465,
#  'spring': 5999,
#  'ice': 3734,
#  'far': 2802,
#  'long': 4171,
#  'branch': 1517,
#  'break': 1520,
#  'fell': 2881,
#  'water': 6775,
#  'closed': 1878,
#  'head': 3558,
#  '. far': 590,
#  'fell ,': 2882,
#  ', water': 444,
#  'head .': 3559,
#  'accusations': 982,
#  'directed': 2370,
#  'acting': 994,
#  'close': 1861,
#  ', close': 170,
#  'close .': 1863,
#  'failing': 2770,
#  'examination .': 2675,
#  'drunkard': 2528,
#  'started': 6022,
#  'bleeding': 1431,
#  'wet': 6838,
#  'disgust': 2403,
#  'turned': 6540,
#  ', started': 404,
#  'adult': 1020,
#  'caught': 1699,
#  'lying': 4259,
#  'badly': 1314,
#  'badly .': 1316,
#  'environment': 2629,
#  'worse': 6920,
#  'privileged': 5155,
#  'seen': 5710,
#  'person seen': 4996,
#  'seen long': 5712,
#  'long time': 4176,
#  'seen long time': 5713,
#  'long time .': 4178,
#  'knocked': 3952,
#  ', child': 166,
#  'child ,': 1773,
#  ', nearly': 337,
#  'nearly knocked': 4636,
#  'knocked car': 3953,
#  'car .': 1654,
#  ', child ,': 167,
#  'knocked car .': 3954,
#  'heard': 3567,
#  'radio': 5271,
#  'football': 3060,
#  'match': 4324,
#  'ended': 2598,
#  'died': 2337,
#  'normal': 4700,
#  'behave': 1366,
#  'heard radio': 3577,
#  'football match': 3063,
#  ', people': 346,
#  'people died': 4954,
#  'died .': 2341,
#  '. understand': 799,
#  'way .': 6781,
#  'lonely': 4168,
#  'lot': 4216,
#  'shut': 5824,
#  'appartment': 1136,
#  'happens': 3521,
#  'particular': 4879,
#  'lonely ,': 4169,
#  '. happens': 641,
#  'particular time': 4881,
#  'mass': 4320,
#  'killing': 3928,
#  'going': 3319,
#  'world': 6910,
#  'world .': 6912,
#  'lied': 4097,
#  'precise': 5108,
#  'cancelled': 1641,
#  'meeting': 4367,
#  'lied ,': 4098,
#  'accepted': 960,
#  'course': 2054,
#  'finance': 3007,
#  'bus': 1576,
#  'drove': 2514,
#  'right': 5498,
#  'leg': 4065,
#  'event': 2650,
#  'frightening': 3208,
#  'wait': 6707,
#  'ward': 6753,
#  'hours': 3695,
#  'began': 1359,
#  'frightened': 3206,
#  'leg .': 4066,
#  '. event': 576,
#  ', frightened': 248,
#  'frightened .': 3207,
#  ', frightened .': 249,
#  'summer': 6168,
#  'job': 3873,
#  'looked': 4188,
#  'learn': 4032,
#  'summer job': 6173,
#  'job ,': 3874,
#  ', looked': 315,
#  'student': 6108,
#  'accepted student': 966,
#  'just': 3902,
#  'moved': 4535,
#  'new': 4661,
#  'kitchen': 3938,
#  'clean': 1846,
#  'felt': 2896,
#  'disgusted': 2408,
#  'just moved': 3906,
#  'moved new': 4539,
#  'kitchen .': 3939,
#  '. going': 632,
#  '. felt': 599,
#  'felt disgusted': 2916,
#  'disgusted .': 2409,
#  '. felt disgusted': 606,
#  'felt disgusted .': 2917,
#  'elder': 2570,
#  'brother': 1546,
#  'relationship': 5394,
#  'ashamed': 1194,
#  'talk': 6222,
#  'elder brother': 2571,
#  'good relationship': 3354,
#  'feel ashamed': 2851,
#  'age': 1044,
#  'preferred': 5110,
#  'lunch': 4255,
#  'accounts': 981,
#  'passed': 4899,
#  'points': 5071,
#  'passed exam': 4907,
#  'cottage': 2042,
#  'large': 3988,
#  'forest': 3077,
#  'dark': 2129,
#  ', dark': 177,
#  'dark .': 2131,
#  'railway': 5274,
#  'station': 6042,
#  'good-bye': 3357,
#  'railway station': 5275,
#  'good-bye .': 3358,
#  'small': 5903,
#  'italy': 3864,
#  'probably': 5157,
#  'italy .': 3865,
#  'told': 6407,
#  'party': 4889,
#  'enjoy': 2612,
#  'came': 1610,
#  'understood': 6588,
#  'told friend': 6418,
#  'friend going': 3140,
#  'going party': 3330,
#  'came .': 1612,
#  'told friend going': 6420,
#  'reason': 5339,
#  'break-up': 1521,
#  'finished': 3022,
#  "friend 's": 3112,
#  'relationship girlfriend': 5403,
#  'girlfriend .': 3293,
#  '. finished': 618,
#  'finished .': 3023,
#  'relationship girlfriend .': 5404,
#  'absolutely': 950,
#  'certain': 1724,
#  'failed': 2750,
#  'failed .': 2751,
#  'denmark': 2230,
#  'storm': 6085,
#  'blown': 1439,
#  ';': 909,
#  'scared': 5643,
#  'till': 6372,
#  'managed': 4300,
#  'locked': 4163,
#  'missed': 4433,
#  'tram': 6476,
#  'home': 3634,
#  'walk': 6716,
#  'pouring': 5098,
#  'rain': 5276,
#  'worms': 6916,
#  'food': 3054,
#  'eaten': 2557,
#  'intoxicated': 3843,
#  'police': 5073,
#  'took': 6442,
#  'later': 4002,
#  'contacted': 2010,
#  'parents': 4859,
#  'came took': 1631,
#  'took away': 6444,
#  'away ,': 1283,
#  ', later': 297,
#  'parents .': 4862,
#  'meant': 4346,
#  'hear': 3565,
#  'hear .': 3566,
#  'won': 6881,
#  'trip': 6514,
#  'greece': 3444,
#  'competition': 1951,
#  'competition .': 1952,
#  'looking': 4192,
#  'comes': 1922,
#  'elderly': 2573,
#  'man': 4289,
#  'complained': 1953,
#  'work ,': 6895,
#  'lecture': 4046,
#  'lecture .': 4048,
#  'alcoholic': 1071,
#  'stood': 6077,
#  'counter': 2044,
#  'discussing': 2397,
#  'looks': 4196,
#  'guy': 3484,
#  'listening': 4140,
#  'listening .': 4141,
#  'colleague': 1896,
#  'manager': 4301,
#  'liked': 4121,
#  'liked .': 4123,
#  'birthday': 1416,
#  'closest': 1882,
#  'pleasant': 5059,
#  'say': 5634,
#  'happy': 3524,
#  "'s birthday": 33,
#  'birthday party': 1419,
#  'closest friends': 1884,
#  'friends .': 3184,
#  'good friends': 3350,
#  "friend 's birthday": 3113,
#  'good friends .': 3351,
#  'friday': 3108,
#  'night': 4677,
#  'heavy': 3589,
#  'surface': 6191,
#  'seconds': 5700,
#  'way home': 6784,
#  'friday night': 3109,
#  '. lost': 679,
#  'mad': 4266,
#  'dad': 2116,
#  'case': 1687,
#  'love .': 4231,
#  'smelling': 5910,
#  'masturbating': 4322,
#  'masturbating .': 4323,
#  'help': 3591,
#  'home .': 3639,
#  'felt happy': 2936,
#  'athens': 1241,
#  'holiday': 3627,
#  'plane': 5041,
#  'crash': 2070,
#  'holiday .': 3629,
#  'crash .': 2071,
#  'stole': 6069,
#  'bike': 1401,
#  'bike .': 1402,
#  'list': 4135,
#  'books': 1461,
#  '``': 919,
#  'oh': 4751,
#  'god': 3315,
#  '!': 0,
#  "''": 8,
#  'course ,': 2055,
#  ', thought': 422,
#  "! ''": 1,
#  'newspaper': 4670,
#  'article': 1193,
#  'future': 3226,
#  'eating': 2558,
#  'showed': 5819,
#  'frog': 3209,
#  'pieces': 5029,
#  'bread': 1518,
#  'read newspaper': 5304,
#  'newspaper article': 4671,
#  'bread .': 1519,
#  'read newspaper article': 5305,
#  'dropped': 2513,
#  'bottle': 1476,
#  'state': 6038,
#  'store': 6083,
#  'laughing': 4018,
#  'started laughing': 6028,
#  'laughing .': 4019,
#  'started laughing .': 6029,
#  'young': 6980,
#  '-': 455,
#  '14': 845,
#  'caught .': 1701,
#  'family': 2791,
#  'gets': 3254,
#  'week': 6796,
#  'everybody': 2655,
#  'feels': 2877,
#  'free': 3102,
#  'planned': 5042,
#  'works': 6909,
#  '. everybody': 578,
#  'daughter': 2142,
#  'ran': 5281,
#  '(': 74,
#  'finally': 3004,
#  'bed': 1351,
#  'sleep': 5885,
#  ')': 110,
#  'old daughter': 4758,
#  'daughter .': 2144,
#  '. ran': 722,
#  'looked .': 4189,
#  '. (': 477,
#  'finally ,': 3005,
#  ', gone': 256,
#  'year old daughter': 6953,
#  'hurt': 3717,
#  'hurt .': 3719,
#  'marriage': 4314,
#  'makes': 4278,
#  'advances': 1023,
#  'does': 2446,
#  'want': 6734,
#  'want .': 6735,
#  'spanked': 5960,
#  'anger': 1086,
#  'regretted': 5384,
#  'terribly': 6302,
#  'terribly .': 6303,
#  'repeat': 5437,
#  'stockholm': 6068,
#  'boyfriend': 1490,
#  'month': 4469,
#  'boyfriend went': 1510,
#  'went away': 6815,
#  'worked': 6900,
#  'holidays': 3631,
#  'studied': 6120,
#  'summer holidays': 6172,
#  'month .': 4470,
#  'dog': 2449,
#  'left': 4060,
#  'outside': 4812,
#  'shop': 5797,
#  'shop .': 5799,
#  'promised': 5177,
#  'promise': 5175,
#  'promised help': 5182,
#  'help friend': 3593,
#  'promise .': 5176,
#  'examinations': 2681,
#  'examinations .': 2682,
#  'day': 2145,
#  'economics': 2560,
#  'day told': 2164,
#  'economics .': 2561,
#  'taking': 6220,
#  'cut': 2112,
#  'park': 4871,
#  'surrounded': 6195,
#  'tried': 6502,
#  'money': 4460,
#  'saved': 5605,
#  'appearance': 1138,
#  'money .': 4462,
#  '. scared': 751,
#  'people .': 4947,
#  'restaurant': 5472,
#  'observed': 4726,
#  'cheating': 1762,
#  'foreigners': 3076,
#  'i.e': 3732,
#  'speaking': 5964,
#  'expression': 2727,
#  'used': 6654,
#  'speaking .': 5965,
#  '. anger': 491,
#  'used .': 6655,
#  'begining': 1364,
#  'afraid': 1034,
#  'problems': 5160,
#  'manage': 4298,
#  'thoughts': 6358,
#  'subject': 6137,
#  'consequences': 1996,
#  'manage .': 4299,
#  'future .': 3227,
#  'walking': 6723,
#  'town': 6462,
#  'noticed': 4709,
#  'influence': 3790,
#  'alcohol': 1068,
#  'terrified': 6306,
#  'driving': 2507,
#  'pedestrian': 4937,
#  'street': 6093,
#  'gestures': 3253,
#  'policemen': 5077,
#  'influence alcohol': 3791,
#  'alcohol .': 1070,
#  'street .': 6095,
#  'influence alcohol .': 3792,
#  'revealed': 5493,
#  'knew': 3942,
#  'discovered': 2392,
#  'nature': 4624,
#  'mentioned': 4382,
#  'earlier': 2541,
#  ', felt': 232,
#  'felt ashamed': 2903,
#  'earlier .': 2543,
#  ', felt ashamed': 233,
#  'dishonest': 2421,
#  'gives': 3304,
#  'different': 2355,
#  'truth': 6531,
#  'mistakes': 4440,
#  'aware': 1281,
#  'wrong .': 6934,
#  'exams': 2690,
#  'marks': 4312,
#  'passed exams': 4909,
#  'marks .': 4313,
#  'father': 2811,
#  'ill': 3749,
#  'waiting': 6710,
#  'results': 5480,
#  'tests': 6313,
#  'father ill': 2824,
#  'waiting results': 6714,
#  'tests .': 6314,
#  'got': 3362,
#  'got caught': 3369,
#  'failed exam': 2755,
#  'exam .': 2666,
#  'failed exam .': 2756,
#  'prepared': 5121,
#  'group': 3454,
#  'thoroughly': 6346,
#  'members': 4375,
#  'result': 5475,
#  'poor': 5080,
#  ', result': 367,
#  'result poor': 5477,
#  'poor .': 5081,
#  'house': 3700,
#  'recovered': 5368,
#  'lazy': 4025,
#  'work hard': 6897,
#  'later .': 4004,
#  'gave': 3240,
#  'birth': 1412,
#  'alive': 1073,
#  'early': 2544,
#  'lung': 4257,
#  'happened': 3513,
#  'ago': 1049,
#  'gave birth': 3242,
#  'birth son': 1415,
#  '. happened': 640,
#  'happened year': 3518,
#  'year ago': 6950,
#  'ago .': 1052,
#  'gave birth son': 3243,
#  'year ago .': 6951,
#  'cancer': 1644,
#  'did know': 2281,
#  'live .': 4153,
#  'asked': 1208,
#  'despite': 2252,
#  'fact': 2743,
#  'colleague asked': 1898,
#  'asked help': 1212,
#  ', despite': 182,
#  'despite fact': 2253,
#  'salary': 5592,
#  'expecting': 2707,
#  'little': 4143,
#  'appreciated': 1153,
#  'appreciated .': 1154,
#  'garden': 3235,
#  'hand': 3498,
#  'hand .': 3500,
#  'met': 4392,
#  'troubles': 6522,
#  'touch': 6457,
#  'met friend': 4395,
#  'friend seen': 3165,
#  'got touch': 3398,
#  'friend seen long': 3166,
#  'angry': 1092,
#  'mother': 4487,
#  'trivial': 6519,
#  'mood': 4480,
#  'really': 5318,
#  'needed': 4641,
#  'support': 6184,
#  'reacted': 5296,
#  'wrongly': 6937,
#  'got angry': 3364,
#  'angry mother': 1102,
#  'bad mood': 1309,
#  'knew mother': 3947,
#  'mother really': 4515,
#  'really needed': 5334,
#  'support .': 6186,
#  '. reacted': 724,
#  'wrongly .': 6938,
#  'eve': 2643,
#  'steps': 6064,
#  'kissed': 3936,
#  'new year': 4664,
#  "year 's": 6944,
#  "'s eve": 45,
#  ', met': 329,
#  'met girlfriend': 4398,
#  'parents home': 4867,
#  "new year 's": 4665,
#  "year 's eve": 6945,
#  'plain': 5039,
#  'clothes': 1885,
#  'overturned': 4824,
#  'fast': 2807,
#  'situation': 5868,
#  'car driving': 1662,
#  '. driving': 570,
#  'driving fast': 2509,
#  ', afraid': 134,
#  'consequences .': 1997,
#  'changed': 1748,
#  'written': 6930,
#  'written .': 6931,
#  '. considered': 538,
#  'acquaintance': 989,
#  'expected': 2704,
#  'depressed': 2237,
#  'family died': 2797,
#  'cancer .': 1645,
#  '. expected': 581,
#  'expected ,': 2705,
#  'felt depressed': 2910,
#  'depressed .': 2239,
#  'picture': 5026,
#  'post': 5092,
#  'totally': 6455,
#  'injured': 3802,
#  'passengers': 4920,
#  'damaged': 2120,
#  "n't": 4555,
#  'bodies': 1450,
#  'scene': 5646,
#  ', totally': 430,
#  '. car': 527,
#  'scene accident': 5648,
#  'sexual': 5765,
#  'intercourse': 3836,
#  'desire': 2247,
#  'curiosity': 2109,
#  'jump': 3897,
#  'sexual intercourse': 5766,
#  'man .': 4292,
#  'bed .': 1353,
#  '. ashamed': 501,
#  'ashamed .': 1195,
#  '. ashamed .': 502,
#  'laziness': 4024,
#  'term': 6295,
#  'completely': 1955,
#  'university': 6613,
#  'wanted': 6738,
#  'extent': 2728,
#  'protest': 5197,
#  "'": 5,
#  'expectations': 2702,
#  ', failed': 215,
#  'university .': 6615,
#  '. wanted': 806,
#  'wanted ,': 6739,
#  "parents '": 4860,
#  'expectations .': 2703,
#  'studies .': 6124,
#  'intentions': 3833,
#  'alley': 1075,
#  'wednesday': 6795,
#  'night .': 4682,
#  'news': 4667,
#  'south': 5954,
#  'africa': 1038,
#  'policeman': 5076,
#  'black': 1424,
#  't.v saw': 6208,
#  'south africa': 5955,
#  'africa .': 1039,
#  'south africa .': 5956,
#  'having': 3535,
#  'boring': 1463,
#  'pages': 4835,
#  'thought having': 6356,
#  'having read': 3549,
#  'english .': 2606,
#  'inability': 3778,
#  'positively': 5088,
#  'group .': 3456,
#  'feelings guilt': 2876,
#  'cafeteria': 1598,
#  'extremely': 2731,
#  'manners': 4304,
#  'food ,': 3055,
#  ', having': 270,
#  'bad manners': 1307,
#  'manners .': 4305,
#  'bad manners .': 1308,
#  'guess': 3465,
#  'talked': 6225,
#  'ashamed having': 1197,
#  'unpleasant': 6635,
#  'sister': 5847,
#  'history': 3618,
#  'abortion': 941,
#  'perfectly': 4964,
#  'boy': 1481,
#  'sister -': 5851,
#  'boy .': 1485,
#  'emotionally': 2586,
#  'deep': 2212,
#  'sister born': 5853,
#  ', took': 429,
#  'took long': 6447,
#  'starting': 6035,
#  'project': 5172,
#  'teacher': 6245,
#  'helpful': 3598,
#  ', teacher': 415,
#  'openly': 4783,
#  'let': 4074,
#  'girl': 3268,
#  'let ,': 4075,
#  'girl .': 3274,
#  'felt disgust': 2913,
#  'boyfriend time': 1507,
#  'time ,': 6377,
#  ', left': 299,
#  'left .': 4062,
#  'ca': 1594,
#  "ca n't": 1595,
#  "n't think": 4604,
#  'think .': 6339,
#  "n't think .": 4605,
#  'aunt': 1265,
#  'offered': 4746,
#  'seat': 5689,
#  'driver': 2501,
#  'killed': 3925,
#  'crashed': 2072,
#  'accident ,': 972,
#  ', aunt': 141,
#  'car ,': 1653,
#  ', driver': 201,
#  'driver .': 2503,
#  'killed car': 3927,
#  'unexpected': 6595,
#  'visit': 6687,
#  'half': 3490,
#  'unexpected visit': 6596,
#  'visit close': 6690,
#  'close friend': 1865,
#  'friend ,': 3121,
#  ", n't": 335,
#  "n't seen": 4593,
#  'half year': 3493,
#  'year .': 6949,
#  'close friend ,': 1866,
#  ", n't seen": 336,
#  'mistake': 4437,
#  'safety': 5578,
#  'shooting': 5796,
#  'range': 5285,
#  'shot': 5809,
#  ', shot': 386,
#  'shot .': 5810,
#  ', shot .': 387,
#  'unfairly': 6600,
#  'treated unfairly': 6492,
#  'unfairly .': 6601,
#  'breaking': 1523,
#  'father died': 2822,
#  'father died .': 2823,
#  'college': 1904,
#  'possible': 5090,
#  'college ,': 1905,
#  'possible .': 5091,
#  'arrive': 1184,
#  'school': 5651,
#  'school friend': 5662,
#  'killed .': 3926,
#  'accused having': 985,
#  "n't got": 4575,
#  'angry .': 1094,
#  'got angry .': 3365,
#  'grandmother': 3422,
#  'grandmother died': 3426,
#  'grandmother died .': 3429,
#  'applicable': 1144,
#  'applicable .': 1145,
#  'couple': 2049,
#  'years': 6960,
#  'fishing': 3029,
#  'lake': 3980,
#  'husband': 3724,
#  'suddenly': 6151,
#  'raining': 5277,
#  'sun': 6176,
#  'shining': 5788,
#  'experienced': 2713,
#  'feeling': 2867,
#  'joy': 3886,
#  'happiness': 3523,
#  'music': 4552,
#  'couple years': 2051,
#  'years ago': 6965,
#  'summer holiday': 6171,
#  'holiday ,': 3628,
#  'husband .': 3727,
#  '. suddenly': 769,
#  'sun shining': 6177,
#  '. experienced': 582,
#  'experienced feeling': 2715,
#  'feeling joy': 2871,
#  'joy ,': 3887,
#  'music .': 4553,
#  'couple years ago': 2052,
#  'reading': 5306,
#  'magazine': 4269,
#  'experiences': 2716,
#  'strange': 6089,
#  'corner': 2036,
#  'home ,': 3635,
#  ', bed': 144,
#  'experiences .': 2717,
#  '( later': 98,
#  'later realized': 4011,
#  'second': 5692,
#  'attitude': 1257,
#  'lecturer': 4050,
#  ', second': 382,
#  'second time': 5693,
#  'lecturer .': 4051,
#  'superior': 6179,
#  'longer': 4180,
#  'limited': 4131,
#  'human': 3711,
#  'sad': 5561,
#  'died ,': 2339,
#  'reading newspaper': 5307,
#  'sad .': 5563,
#  'fat': 2809,
#  'woman': 6874,
#  'asking': 1221,
#  'directions': 2372,
#  'voice': 6698,
#  'disgusting': 2415,
#  'smell': 5907,
#  'urine': 6649,
#  'fat ,': 2810,
#  'voice .': 6699,
#  '. got': 635,
#  'came . felt': 1613,
#  'remark': 5425,
#  'friendly': 3179,
#  ...}

# %%
bayes_classification = MultinomialNB()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y)

# %%
bayes_classification.fit(X_train, y_train)
# Out:
# MultinomialNB(alpha=1.0, class_prior=None, fit_prior=True)

# %%
bayes_pred = bayes_classification.predict(X_test)

# %%
accuracy_score(y_test, bayes_pred)
# Out:
# 0.5569280343716434
